# %% [markdown]
# ## **Buat program dengan pyspark**

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns = ["Nama", "Usia"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+

# %% [markdown]
# ## **Tugas 1**

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34, "Guru", "Membaca", "Laki-laki"), ("Budi", 23, "Chef", "Memasak", "Laki-laki"), ("Citra", 29, "Pelukis", "Melukis", "Perempuan"), ("Dina", 45, "Penulis", "Menulis", "Perempuan")]
columns = ["Nama", "Usia", "Pekerjaan", "Hobi", "Gender"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()
# Out:
# +-----+----+---------+-------+---------+
# | Nama|Usia|Pekerjaan|   Hobi|   Gender|
# +-----+----+---------+-------+---------+
# |  Ali|  34|     Guru|Membaca|Laki-laki|
# | Budi|  23|     Chef|Memasak|Laki-laki|
# |Citra|  29|  Pelukis|Melukis|Perempuan|
# | Dina|  45|  Penulis|Menulis|Perempuan|
# +-----+----+---------+-------+---------+

# %% [markdown]
# ## **Memanipulasi Data dengan PySpark**

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns = ["Nama", "Usia"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()

# Filtering data
df_filtered = df.filter(df['Usia'] > 30)
df_filtered.show()

# Menghitung rata-rata usia
from pyspark.sql.functions import avg
df.groupBy().agg(avg("Usia")).show()

# Mengurutkan data berdasarkan usia
df_sorted = df.orderBy("Usia", ascending=False)
df_sorted.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
# +----+----+
# |Nama|Usia|
# +----+----+
# | Ali|  34|
# |Dina|  45|
# +----+----+
#
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+
#
# +-----+----+
# | Nama|Usia|
# +-----+----+
# | Dina|  45|
# |  Ali|  34|
# |Citra|  29|
# | Budi|  23|
# +-----+----+

# %% [markdown]
# ## **Tugas 2**

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
print("Data Asli:")
data = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns = ["Nama", "Usia"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()

# Filtering data
print("Data Setelah Filtering (usia yang lebih dari 25 tahun):")
df_filtered = df.filter(df['Usia'] > 25)
df_filtered.show()

# Menghitung rata-rata usia
print("Rata-rata Usia:")
from pyspark.sql.functions import avg
df.groupBy().agg(avg("Usia")).show()

# Mengurutkan data berdasarkan usia (dari yang paling muda)
print("Data Setelah Diurutkan dari yang paling muda:")
df_sorted = df.orderBy("Usia", ascending=True)
df_sorted.show()
# Out:
# Data Asli:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
# Data Setelah Filtering (usia yang lebih dari 25 tahun):
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
# Rata-rata Usia:
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+
#
# Data Setelah Diurutkan dari yang paling muda:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# | Budi|  23|
# |Citra|  29|
# |  Ali|  34|
# | Dina|  45|
# +-----+----+

# %% [markdown]
# ## **Buat DataFrame menggunakan Pandas**

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Usia": [34, 23, 29, 45]}
df_pandas = pd.DataFrame(data_pandas)

# Menampilkan DataFrame Pandas
df_pandas
# Out:
#     Nama  Usia
# 0    Ali    34
# 1   Budi    23
# 2  Citra    29
# 3   Dina    45

# %% [markdown]
# ### **Tugas 3**

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Usia": [34, 23, 29, 45], "Pekerjaan": ["Guru", "Chef", "Pelukis", "Penulis"], "Hobi": ["Membaca", "Memasak", "Melukis", "Menulis"], "Gender": ["Laki-laki", "Laki-laki", "Perempuan", "Perempuan"]}
df_pandas = pd.DataFrame(data_pandas)

# Data Asli
print("Data Asli:")
df_pandas.to_string(index=False)
display(df_pandas)

# Data Setelah Diurutkan dari yang paling muda
df_sorted = df_pandas.sort_values("Usia", ascending=True)
print("\nData Setelah Diurutkan dari yang paling muda:")
df_sorted.to_string(index=False)
display(df_sorted)

# Filtering data (usia > 25)
print("\nData Setelah Filtering (usia yang lebih dari 25 tahun):")
df_pandas_filtered = df_pandas[df_pandas['Usia'] > 25]
display(df_pandas_filtered)
# Out:
# Data Asli:
#     Nama  Usia Pekerjaan     Hobi     Gender
# 0    Ali    34      Guru  Membaca  Laki-laki
# 1   Budi    23      Chef  Memasak  Laki-laki
# 2  Citra    29   Pelukis  Melukis  Perempuan
# 3   Dina    45   Penulis  Menulis  Perempuan
# Data Setelah Diurutkan dari yang paling muda:
#     Nama  Usia Pekerjaan     Hobi     Gender
# 1   Budi    23      Chef  Memasak  Laki-laki
# 2  Citra    29   Pelukis  Melukis  Perempuan
# 0    Ali    34      Guru  Membaca  Laki-laki
# 3   Dina    45   Penulis  Menulis  Perempuan
# Data Setelah Filtering (usia yang lebih dari 25 tahun):
#     Nama  Usia Pekerjaan     Hobi     Gender
# 0    Ali    34      Guru  Membaca  Laki-laki
# 2  Citra    29   Pelukis  Melukis  Perempuan
# 3   Dina    45   Penulis  Menulis  Perempuan

# %% [markdown]
# ## **Penggunaan Pandas untuk operasi lebih kompleks**

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Usia": [34, 23, 29, 45]}
df_pandas = pd.DataFrame(data_pandas)

# Membuat DataFrame kedua
data_pandas_2 = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas_2 = pd.DataFrame(data_pandas_2)

# Join antara dua DataFrame
df_joined = pd.merge(df_pandas, df_pandas_2, on="Nama")
print(df_joined)

# Menghitung statistik deskriptif
print(df_pandas.describe())

# Plotting Data
import matplotlib.pyplot as plt
df_pandas['Usia'].plot(kind='bar')
plt.show()
# Out:
#     Nama  Usia Pekerjaan
# 0    Ali    34    Dokter
# 1   Budi    23      Guru
# 2  Citra    29  Insinyur
# 3   Dina    45   Perawat
#             Usia
# count   4.000000
# mean   32.750000
# std     9.322911
# min    23.000000
# 25%    27.500000
# 50%    31.500000
# 75%    36.750000
# max    45.000000

# %% [markdown]
# ### **Tugas 4**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# DataFrame pertama
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Usia": [34, 23, 29, 45]}
df_pandas = pd.DataFrame(data_pandas)

# DataFrame kedua
data_pandas_2 = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas_2 = pd.DataFrame(data_pandas_2)

# Join kedua DataFrame berdasarkan kolom "Nama"
df_joined = pd.merge(df_pandas, df_pandas_2, on="Nama")
print("Data Setelah Digabung:")
df_joined.to_string(index=False)
display(df_joined)

# Statistik deskriptif
print("\nStatistik Deskriptif Usia:")
display(df_pandas.describe())

# Visualisasi: Bar chart usia tiap orang
df_joined.plot(x="Nama", y="Usia", kind="bar", legend=False, color="skyblue", edgecolor="black")
plt.title("Usia Tiap Orang")
plt.ylabel("Usia")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Data Setelah Digabung:
#     Nama  Usia Pekerjaan
# 0    Ali    34    Dokter
# 1   Budi    23      Guru
# 2  Citra    29  Insinyur
# 3   Dina    45   Perawat
# Statistik Deskriptif Usia:
#             Usia
# count   4.000000
# mean   32.750000
# std     9.322911
# min    23.000000
# 25%    27.500000
# 50%    31.500000
# 75%    36.750000
# max    45.000000

# %% [markdown]
# ## **Mengonversi DataFrame antara PySpark dan Pandas**

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
display(df_pandas_from_spark)
df_spark_from_pandas.show()
# Out:
#     Nama  Usia
# 0    Ali    34
# 1   Budi    23
# 2  Citra    29
# 3   Dina    45
# +-----+----+---------+-------+---------+
# | Nama|Usia|Pekerjaan|   Hobi|   Gender|
# +-----+----+---------+-------+---------+
# |  Ali|  34|     Guru|Membaca|Laki-laki|
# | Budi|  23|     Chef|Memasak|Laki-laki|
# |Citra|  29|  Pelukis|Melukis|Perempuan|
# | Dina|  45|  Penulis|Menulis|Perempuan|
# +-----+----+---------+-------+---------+

# %% [markdown]
# ## **Tugas 5: menggabungkan data yang Anda buat di PySpark dengan data dari Pandas, kemudian lakukan analisis sederhana seperti menghitung rata-rata usia.**

# %%
# Import library
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg

# Buat Spark Session
spark = SparkSession.builder.appName("Tugas5").getOrCreate()

# Data PySpark
data_spark = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns_spark = ["Nama", "Usia"]

df_spark = spark.createDataFrame(data_spark, columns_spark)
print("Data PySpark")

# tampilkan
df_spark.show()

# Data Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas = pd.DataFrame(data_pandas)

print("\nData Pandas")
display(df_pandas)

# Konversi Pandas -> PySpark agar bisa digabung
df_pandas_to_spark = spark.createDataFrame(df_pandas)

# Gabungkan (join) berdasarkan Nama
df_joined = df_spark.join(df_pandas_to_spark, on="Nama")

print("\nData Gabungan (PySpark Join)")
df_joined.show()

# Analisis sederhana -> Rata-rata usia
print("\nRata-rata Usia")
df_joined.agg(avg("Usia")).show()
# Out:
# Data PySpark
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
#
# Data Pandas
#     Nama Pekerjaan
# 0    Ali    Dokter
# 1   Budi      Guru
# 2  Citra  Insinyur
# 3   Dina   Perawat
# Data Gabungan (PySpark Join)
# +-----+----+---------+
# | Nama|Usia|Pekerjaan|
# +-----+----+---------+
# |  Ali|  34|   Dokter|
# | Budi|  23|     Guru|
# |Citra|  29| Insinyur|
# | Dina|  45|  Perawat|
# +-----+----+---------+
#
#
# Rata-rata Usia
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+

# %% [markdown]
# ## **Konversi Data antara PySpark dan Pandas**

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
display(df_pandas_from_spark)
df_spark_from_pandas.show()
# Out:
#     Nama  Usia
# 0    Ali    34
# 1   Budi    23
# 2  Citra    29
# 3   Dina    45
# +-----+----+---------+-------+---------+
# | Nama|Usia|Pekerjaan|   Hobi|   Gender|
# +-----+----+---------+-------+---------+
# |  Ali|  34|     Guru|Membaca|Laki-laki|
# | Budi|  23|     Chef|Memasak|Laki-laki|
# |Citra|  29|  Pelukis|Melukis|Perempuan|
# | Dina|  45|  Penulis|Menulis|Perempuan|
# +-----+----+---------+-------+---------+

# %% [markdown]
# ## Tugas 6: Gabungkan data dari PySpark dan Pandas, lalu lakukan operasi statistik seperti menghitung nilai maksimum usia

# %%
# Import library
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import max

# Buat Spark Session
spark = SparkSession.builder.appName("Tugas5").getOrCreate()

# Data PySpark
data_spark = [("Ali", 34), ("Budi", 23), ("Citra", 29), ("Dina", 45)]
columns_spark = ["Nama", "Usia"]

df_spark = spark.createDataFrame(data_spark, columns_spark)
print("Data PySpark")

# tampilkan
df_spark.show()

# Data Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas = pd.DataFrame(data_pandas)

print("\nData Pandas")
display(df_pandas)

# Konversi Pandas -> PySpark agar bisa digabung
df_pandas_to_spark = spark.createDataFrame(df_pandas)

# Gabungkan (join) berdasarkan Nama
df_joined = df_spark.join(df_pandas_to_spark, on="Nama")

print("\nData Gabungan (PySpark Join)")
df_joined.show()

# Operasi Statistik -> nilai maksimum usia
print("\nNilai maksimum usia")
df_joined.agg(max("Usia")).show()
# Out:
# Data PySpark
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
#
# Data Pandas
#     Nama Pekerjaan
# 0    Ali    Dokter
# 1   Budi      Guru
# 2  Citra  Insinyur
# 3   Dina   Perawat
# Data Gabungan (PySpark Join)
# +-----+----+---------+
# | Nama|Usia|Pekerjaan|
# +-----+----+---------+
# |  Ali|  34|   Dokter|
# | Budi|  23|     Guru|
# |Citra|  29| Insinyur|
# | Dina|  45|  Perawat|
# +-----+----+---------+
#
#
# Nilai maksimum usia
# +---------+
# |max(Usia)|
# +---------+
# |       45|
# +---------+
